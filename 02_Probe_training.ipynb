# %% [markdown]
# <a href="https://colab.research.google.com/github/Narthanasiva/Neuron_level_Phoneme_Explanation/blob/main/02_Probe_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Step 01: Setup Google Drive and Imports**

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# ============ CONFIG ============
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
EPOCHS = 15
BATCH_SIZE = 512
LR = 1e-3
FEATURES = ["voiced", "fricative", "nasal"]
NUM_LAYERS = 13
EMB_DIM = 768  # WavLM embedding size
HIDDEN_DIM = 200



# ============ PATHS =============

# Paths for dataset and results
ROOT_DIR = "/content/drive/MyDrive/00_RESEARCH_MSC_00/Final_Phonetic_Identification"
DATA_DIR = f"{ROOT_DIR}/01_layer_datasets"
MODEL_DIR = f"{ROOT_DIR}/02_Trained_models"
METRIC_DIR = f"{ROOT_DIR}/03_Evaluation_metrics_of_probes"

# Create output folders if they don't exist
import os
os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(METRIC_DIR, exist_ok=True)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import pandas as pd
import json
import os
from pathlib import Path
from typing import Tuple

# %% [markdown]
# # **Step 02: Define the PyTorch MLP Model**

# %%
import torch
import torch.nn as nn

class MLPProbe(nn.Module):
    """
    One-hidden-layer MLP probe: 768 → 200 → 1 (with sigmoid)
    """
    def __init__(self, input_dim=EMB_DIM, hidden_dim=HIDDEN_DIM):
        super(MLPProbe, self).__init__()
        self.hidden = nn.Linear(input_dim, hidden_dim)
        self.output = nn.Linear(hidden_dim, 1)
        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()  # Used only for inference

    def forward(self, x):
        x = self.hidden(x)
        x = self.relu(x)
        x = self.output(x)  # No sigmoid here for training (BCEWithLogits)
        return x

# %% [markdown]
# # **Step 3: Load Dataset for a Specific Layer + Feature for training and testing**

# %%
def load_dataset(layer: int, feature: str):
    """
    Load training and test data for a specific layer and feature.
    """
    train_df = pd.read_pickle(f"{DATA_DIR}/layer_{layer}_train.pkl")
    test_df = pd.read_pickle(f"{DATA_DIR}/layer_{layer}_test.pkl")

    X_train = torch.tensor(np.stack(train_df["embedding"]), dtype=torch.float32)
    X_test  = torch.tensor(np.stack(test_df["embedding"]), dtype=torch.float32)
    y_train = torch.tensor(train_df[feature].values, dtype=torch.float32).unsqueeze(1)
    y_test  = torch.tensor(test_df[feature].values, dtype=torch.float32).unsqueeze(1)

    return X_train.to(DEVICE), y_train.to(DEVICE), X_test.to(DEVICE), y_test.to(DEVICE)

# %% [markdown]
# # **Step 4: Train the MLP Model**

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset

def train_model(model: nn.Module,
                X_train: torch.Tensor,
                y_train: torch.Tensor,
                epochs: int = 25,
                batch_size: int = 512,
                lr: float = 1e-3) -> nn.Module:
    """
    Trains a 1-hidden-layer MLP binary classifier using PyTorch.

    Parameters:
    -----------
    model : nn.Module
        The MLP model to be trained (input → hidden → output).

    X_train : torch.Tensor
        Training features (shape: [num_samples, 768]).

    y_train : torch.Tensor
        Binary labels (shape: [num_samples, 1]), values 0 or 1.

    epochs : int
        Number of training epochs (full passes over the dataset).

    batch_size : int
        Number of samples per mini-batch.

    lr : float
        Learning rate for the Adam optimizer.

    Returns:
    --------
    model : nn.Module
        The trained model with updated weights.
    """

    # Loss function: Binary cross-entropy with sigmoid built-in
    criterion = nn.BCEWithLogitsLoss()

    # Optimizer: Adam adjusts learning based on gradients
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)

    # Combine input features and labels into a single dataset
    dataset = TensorDataset(X_train, y_train)

    # Load the dataset in mini-batches (shuffled for better learning)
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

    # Set model in training mode (important for things like dropout or batchnorm)
    model.train()

    # Enable gradient calculation (required during training)
    with torch.set_grad_enabled(True):
        # Loop over the number of full passes over the dataset
        for epoch in range(epochs):
            total_loss = 0  # Keep track of total loss in this epoch

            # Go through the dataset in mini-batches
            for xb, yb in dataloader:
                optimizer.zero_grad()        # Reset gradients from the last step
                logits = model(xb)           # Forward pass: get raw predictions (logits)
                loss = criterion(logits, yb) # Calculate loss between prediction and truth
                loss.backward()              # Backward pass: compute gradients
                optimizer.step()             # Update weights using gradients

                total_loss += loss.item()    # Track total loss

            # Print average loss for this epoch
            avg_loss = total_loss / len(dataloader)
            print(f"Epoch {epoch+1}/{epochs} - Loss: {avg_loss:.4f}")

    return model  # Return the trained model

# %% [markdown]
# # **Step 5: Evaluate the Model**

# %%
import torch
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

def evaluate_model(model: torch.nn.Module,
                   X_test: torch.Tensor,
                   y_test: torch.Tensor) -> dict:
    """
    Evaluates a trained binary classifier on test data and returns key metrics.

    Parameters:
    -----------
    model : nn.Module
        The trained PyTorch MLP model.

    X_test : torch.Tensor
        Test features (shape: [num_samples, 768]).

    y_test : torch.Tensor
        True binary labels (shape: [num_samples, 1]), values are 0 or 1.

    Returns:
    --------
    metrics : dict
        A dictionary containing accuracy, precision, recall, and F1-score.
    """

    # Put the model in evaluation mode (disables dropout, etc.)
    model.eval()

    # We don’t need to compute gradients during evaluation
    with torch.no_grad():
        # Get the model's output logits (before sigmoid)
        logits = model(X_test)

        # Apply sigmoid to get probabilities between 0 and 1
        probs = torch.sigmoid(logits)

        # Convert probabilities to binary predictions (1 if ≥ 0.5, else 0)
        preds = (probs >= 0.5).float()

    # Move predictions and labels to CPU so we can use sklearn
    y_true = y_test.cpu().numpy().ravel()
    y_pred = preds.cpu().numpy().ravel()

    # Compute evaluation metrics
    accuracy  = accuracy_score (y_true, y_pred)
    precision = precision_score(y_true, y_pred, zero_division=0)
    recall    = recall_score   (y_true, y_pred, zero_division=0)
    f1        = f1_score       (y_true, y_pred, zero_division=0)

    # Store all metrics in a dictionary
    metrics = {
        "accuracy": accuracy,
        "precision": precision,
        "recall": recall,
        "f1": f1
    }

    # Print them in a readable format
    print(f"📊 Evaluation Results - Acc: {accuracy:.3f}, Prec: {precision:.3f}, "
          f"Rec: {recall:.3f}, F1: {f1:.3f}")

    return metrics

# %% [markdown]
# # **Step 6: Save Model and Config AND Evaluation metric**

# %%
def save_model(model, layer: int, feature: str):
    layer_dir = Path(MODEL_DIR) / f"layer_{layer}"
    layer_dir.mkdir(parents=True, exist_ok=True)

    torch.save(model.state_dict(), layer_dir / f"{feature}_model.pt")
    with open(layer_dir / f"{feature}_config.json", "w") as f:
        json.dump({"input_dim": 768, "hidden_dim": 256}, f)

# %%
def save_metrics(all_metrics: dict, layer: int):
    with open(Path(METRIC_DIR) / f"layer_{layer}_metrics.json", "w") as f:
        json.dump(all_metrics, f, indent=2)

# %% [markdown]
# # **07. Step 07: Create layers vs f1 score/accuracy**

# %%
import pandas as pd
from pathlib import Path

def save_score_tables(metrics: list, save_dir: Path):
    """
    Creates and saves two CSV files: one for F1 scores and one for accuracy scores.

    Parameters:
    -----------
    metrics : list of dict
        The full list of metrics from evaluate_model() with keys:
        ['layer', 'feature', 'accuracy', 'f1', ...]

    save_dir : Path
        Directory to save the CSV files (e.g., METRIC_DIR)
    """

    # Create a list of unique layers and features
    layers = sorted(set(m["layer"] for m in metrics))
    features = ["voiced", "fricative", "nasal"]

    # Initialize empty DataFrames
    f1_df = pd.DataFrame(columns=["layer"] + features)
    acc_df = pd.DataFrame(columns=["layer"] + features)

    # Fill the DataFrames row by row
    for L in layers:
        row_f1 = {"layer": L}
        row_acc = {"layer": L}
        for feat in features:
            # Find the matching metric dict
            m = next((m for m in metrics if m["layer"] == L and m["feature"] == feat), None)
            if m:
                row_f1[feat] = round(m["f1"], 4)
                row_acc[feat] = round(m["accuracy"], 4)
        f1_df = pd.concat([f1_df, pd.DataFrame([row_f1])], ignore_index=True)
        acc_df = pd.concat([acc_df, pd.DataFrame([row_acc])], ignore_index=True)

    # Save the CSVs
    f1_path = save_dir / "f1_scores.csv"
    acc_path = save_dir / "accuracy_scores.csv"
    f1_df.to_csv(f1_path, index=False)
    acc_df.to_csv(acc_path, index=False)

    print(f"✅ F1 scores saved to: {f1_path}")
    print(f"✅ Accuracy scores saved to: {acc_path}")

# %% [markdown]
# # **MAIN function**

# %%
def main():
    # Step 1: Define all 3 phonetic features you're probing
    FEATURES = ["voiced", "fricative", "nasal"]

    # Directory to save results (customize if needed)
    METRIC_DIR = Path("/content/drive/MyDrive/00_RESEARCH_MSC_00/Final_Phonetic_Identification/03_Evaluation_metrics_of_probes")

    # Store all metrics for all layers and features
    all_metrics = []

    # Step 2: Loop over all 13 WavLM layers (0 to 12)
    for layer in range(13):
        print(f"\n🔍 Processing Layer {layer}")
        layer_metrics = {}  # Dictionary to store metrics for all 3 features in this layer

        # Step 3: Loop over each binary feature (1 model per feature)
        for feature in FEATURES:
            print(f"  ▶ Training for Feature: {feature}")

            # Step 3.1: Load the dataset (X: 768D embeddings, y: 0/1 binary label)
            X_train, y_train, X_test, y_test = load_dataset(layer, feature)

            # Step 3.2: Initialize a fresh model
            model = MLPProbe(input_dim=768, hidden_dim=200)

            # Step 3.3: Train the model using the training data
            train_model(model, X_train, y_train)

            # Step 3.4: Evaluate the trained model using test data
            metrics = evaluate_model(model, X_test, y_test)

            # Step 3.5: Print the evaluation results
            print(f"     ➤ F1-score: {metrics['f1']:.3f}, Accuracy: {metrics['accuracy']:.3f}")

            # Step 3.6: Save the trained model
            save_model(model, layer, feature)

            # Step 3.7: Store this feature’s metrics under the layer
            layer_metrics[feature] = metrics

            # Step 3.8: Add full info to all_metrics (including layer + feature)
            metrics_with_meta = metrics.copy()
            metrics_with_meta.update({"layer": layer, "feature": feature})
            all_metrics.append(metrics_with_meta)

        # Step 4: Save the complete metrics for this layer (all 3 features) as JSON
        save_metrics(layer_metrics, layer)

    # ✅ FINAL STEP: Save overall F1 and accuracy tables as CSVs
    save_score_tables(all_metrics, METRIC_DIR)

    print("\n✅ All layers and features have been trained, evaluated, and saved successfully.")

# %%
main()
# Out:
# 🔍 Processing Layer 0
#   ▶ Training for Feature: voiced
# Epoch 1/25 - Loss: 0.5548
# Epoch 2/25 - Loss: 0.2976
# Epoch 3/25 - Loss: 0.2085
# Epoch 4/25 - Loss: 0.1741
# Epoch 5/25 - Loss: 0.1580
# Epoch 6/25 - Loss: 0.1461
# Epoch 7/25 - Loss: 0.1369
# Epoch 8/25 - Loss: 0.1296
# Epoch 9/25 - Loss: 0.1222
# Epoch 10/25 - Loss: 0.1170
# Epoch 11/25 - Loss: 0.1113
# Epoch 12/25 - Loss: 0.1066
# Epoch 13/25 - Loss: 0.1019
# Epoch 14/25 - Loss: 0.0981
# Epoch 15/25 - Loss: 0.0939
# Epoch 16/25 - Loss: 0.0907
# Epoch 17/25 - Loss: 0.0870
# Epoch 18/25 - Loss: 0.0833
# Epoch 19/25 - Loss: 0.0796
# Epoch 20/25 - Loss: 0.0765
# Epoch 21/25 - Loss: 0.0744
# Epoch 22/25 - Loss: 0.0709
# Epoch 23/25 - Loss: 0.0686
# Epoch 24/25 - Loss: 0.0661
# Epoch 25/25 - Loss: 0.0633
# 📊 Evaluation Results - Acc: 0.868, Prec: 0.855, Rec: 0.906, F1: 0.880
#      ➤ F1-score: 0.880, Accuracy: 0.868
#   ▶ Training for Feature: fricative
# Epoch 1/25 - Loss: 0.5187
# Epoch 2/25 - Loss: 0.2723
# Epoch 3/25 - Loss: 0.1860
# Epoch 4/25 - Loss: 0.1553
# Epoch 5/25 - Loss: 0.1371
# Epoch 6/25 - Loss: 0.1256
# Epoch 7/25 - Loss: 0.1169
# Epoch 8/25 - Loss: 0.1092
# Epoch 9/25 - Loss: 0.1018
# Epoch 10/25 - Loss: 0.0955
# Epoch 11/25 - Loss: 0.0896
# Epoch 12/25 - Loss: 0.0848
# Epoch 13/25 - Loss: 0.0795
# Epoch 14/25 - Loss: 0.0747
# Epoch 15/25 - Loss: 0.0700
# Epoch 16/25 - Loss: 0.0670
# Epoch 17/25 - Loss: 0.0626
# Epoch 18/25 - Loss: 0.0590
# Epoch 19/25 - Loss: 0.0558
# Epoch 20/25 - Loss: 0.0519
# Epoch 21/25 - Loss: 0.0492
# Epoch 22/25 - Loss: 0.0468
# Epoch 23/25 - Loss: 0.0440
# Epoch 24/25 - Loss: 0.0415
# Epoch 25/25 - Loss: 0.0395
# 📊 Evaluation Results - Acc: 0.905, Prec: 0.629, Rec: 0.757, F1: 0.687
#      ➤ F1-score: 0.687, Accuracy: 0.905
#   ▶ Training for Feature: nasal
# Epoch 1/25 - Loss: 0.5331
# Epoch 2/25 - Loss: 0.2796
# Epoch 3/25 - Loss: 0.1584
# Epoch 4/25 - Loss: 0.1056
# Epoch 5/25 - Loss: 0.0810
# Epoch 6/25 - Loss: 0.0662
# Epoch 7/25 - Loss: 0.0574
# Epoch 8/25 - Loss: 0.0517
# Epoch 9/25 - Loss: 0.0484
# Epoch 10/25 - Loss: 0.0451
# Epoch 11/25 - Loss: 0.0430
# Epoch 12/25 - Loss: 0.0410
# Epoch 13/25 - Loss: 0.0390
# Epoch 14/25 - Loss: 0.0375
# Epoch 15/25 - Loss: 0.0357
# Epoch 16/25 - Loss: 0.0342
# Epoch 17/25 - Loss: 0.0330
# Epoch 18/25 - Loss: 0.0319
# Epoch 19/25 - Loss: 0.0301
# Epoch 20/25 - Loss: 0.0286
# Epoch 21/25 - Loss: 0.0274
# Epoch 22/25 - Loss: 0.0264
# Epoch 23/25 - Loss: 0.0249
# Epoch 24/25 - Loss: 0.0239
# Epoch 25/25 - Loss: 0.0227
# 📊 Evaluation Results - Acc: 0.957, Prec: 0.625, Rec: 0.645, F1: 0.635
#      ➤ F1-score: 0.635, Accuracy: 0.957
#
# 🔍 Processing Layer 1
#   ▶ Training for Feature: voiced
# Epoch 1/25 - Loss: 0.5703
# Epoch 2/25 - Loss: 0.3244
# Epoch 3/25 - Loss: 0.2102
# Epoch 4/25 - Loss: 0.1703
# Epoch 5/25 - Loss: 0.1510
# Epoch 6/25 - Loss: 0.1369
# Epoch 7/25 - Loss: 0.1277
# Epoch 8/25 - Loss: 0.1202
# Epoch 9/25 - Loss: 0.1147
# Epoch 10/25 - Loss: 0.1108
# Epoch 11/25 - Loss: 0.1062
# Epoch 12/25 - Loss: 0.1017
# Epoch 13/25 - Loss: 0.0994
# Epoch 14/25 - Loss: 0.0958
# Epoch 15/25 - Loss: 0.0925
# Epoch 16/25 - Loss: 0.0894
# Epoch 17/25 - Loss: 0.0861
# Epoch 18/25 - Loss: 0.0830
# Epoch 19/25 - Loss: 0.0805
# Epoch 20/25 - Loss: 0.0782
# Epoch 21/25 - Loss: 0.0754
# Epoch 22/25 - Loss: 0.0730
# Epoch 23/25 - Loss: 0.0705
# Epoch 24/25 - Loss: 0.0690
# Epoch 25/25 - Loss: 0.0655
# 📊 Evaluation Results - Acc: 0.869, Prec: 0.858, Rec: 0.906, F1: 0.881
#      ➤ F1-score: 0.881, Accuracy: 0.869
#   ▶ Training for Feature: fricative
# Epoch 1/25 - Loss: 0.5296
# Epoch 2/25 - Loss: 0.2904
# Epoch 3/25 - Loss: 0.1939
# Epoch 4/25 - Loss: 0.1571
# Epoch 5/25 - Loss: 0.1349
# Epoch 6/25 - Loss: 0.1201
# Epoch 7/25 - Loss: 0.1094
# Epoch 8/25 - Loss: 0.1020
# Epoch 9/25 - Loss: 0.0952
# Epoch 10/25 - Loss: 0.0888
# Epoch 11/25 - Loss: 0.0834
# Epoch 12/25 - Loss: 0.0787
# Epoch 13/25 - Loss: 0.0748
# Epoch 14/25 - Loss: 0.0707
# Epoch 15/25 - Loss: 0.0682
# Epoch 16/25 - Loss: 0.0649
# Epoch 17/25 - Loss: 0.0620
# Epoch 18/25 - Loss: 0.0594
# Epoch 19/25 - Loss: 0.0568
# Epoch 20/25 - Loss: 0.0540
# Epoch 21/25 - Loss: 0.0523
# Epoch 22/25 - Loss: 0.0510
# Epoch 23/25 - Loss: 0.0481
# Epoch 24/25 - Loss: 0.0456
# Epoch 25/25 - Loss: 0.0442
# 📊 Evaluation Results - Acc: 0.901, Prec: 0.627, Rec: 0.703, F1: 0.662
#      ➤ F1-score: 0.662, Accuracy: 0.901
#   ▶ Training for Feature: nasal
# Epoch 1/25 - Loss: 0.5499
# Epoch 2/25 - Loss: 0.2851
# Epoch 3/25 - Loss: 0.1650
# Epoch 4/25 - Loss: 0.0990
# Epoch 5/25 - Loss: 0.0706
# Epoch 6/25 - Loss: 0.0566
# Epoch 7/25 - Loss: 0.0485
# Epoch 8/25 - Loss: 0.0435
# Epoch 9/25 - Loss: 0.0401
# Epoch 10/25 - Loss: 0.0376
# Epoch 11/25 - Loss: 0.0355
# Epoch 12/25 - Loss: 0.0332
# Epoch 13/25 - Loss: 0.0317
# Epoch 14/25 - Loss: 0.0298
# Epoch 15/25 - Loss: 0.0282
# Epoch 16/25 - Loss: 0.0271
# Epoch 17/25 - Loss: 0.0258
# Epoch 18/25 - Loss: 0.0245
# Epoch 19/25 - Loss: 0.0231
# Epoch 20/25 - Loss: 0.0221
# Epoch 21/25 - Loss: 0.0212
# Epoch 22/25 - Loss: 0.0202
# Epoch 23/25 - Loss: 0.0193
# Epoch 24/25 - Loss: 0.0185
# Epoch 25/25 - Loss: 0.0176
# 📊 Evaluation Results - Acc: 0.968, Prec: 0.719, Rec: 0.742, F1: 0.730
#      ➤ F1-score: 0.730, Accuracy: 0.968
#
# 🔍 Processing Layer 2
#   ▶ Training for Feature: voiced
# Epoch 1/25 - Loss: 0.5655
# Epoch 2/25 - Loss: 0.3317
# Epoch 3/25 - Loss: 0.2044
# Epoch 4/25 - Loss: 0.1554
# Epoch 5/25 - Loss: 0.1329
# Epoch 6/25 - Loss: 0.1178
# Epoch 7/25 - Loss: 0.1094
# Epoch 8/25 - Loss: 0.1028
# Epoch 9/25 - Loss: 0.0976
# Epoch 10/25 - Loss: 0.0929
# Epoch 11/25 - Loss: 0.0894
# Epoch 12/25 - Loss: 0.0858
# Epoch 13/25 - Loss: 0.0825
# Epoch 14/25 - Loss: 0.0798
# Epoch 15/25 - Loss: 0.0771
# Epoch 16/25 - Loss: 0.0746
# Epoch 17/25 - Loss: 0.0729
# Epoch 18/25 - Loss: 0.0704
# Epoch 19/25 - Loss: 0.0678
# Epoch 20/25 - Loss: 0.0668
# Epoch 21/25 - Loss: 0.0641
# Epoch 22/25 - Loss: 0.0626
# Epoch 23/25 - Loss: 0.0604
# Epoch 24/25 - Loss: 0.0588
# Epoch 25/25 - Loss: 0.0570
# 📊 Evaluation Results - Acc: 0.873, Prec: 0.866, Rec: 0.902, F1: 0.884
#      ➤ F1-score: 0.884, Accuracy: 0.873
#   ▶ Training for Feature: fricative
# Epoch 1/25 - Loss: 0.5951
# Epoch 2/25 - Loss: 0.3605
# Epoch 3/25 - Loss: 0.2472
# Epoch 4/25 - Loss: 0.1773
# Epoch 5/25 - Loss: 0.1418
# Epoch 6/25 - Loss: 0.1164
# Epoch 7/25 - Loss: 0.1005
# Epoch 8/25 - Loss: 0.0892
# Epoch 9/25 - Loss: 0.0811
# Epoch 10/25 - Loss: 0.0745
# Epoch 11/25 - Loss: 0.0689
# Epoch 12/25 - Loss: 0.0644
# Epoch 13/25 - Loss: 0.0603
# Epoch 14/25 - Loss: 0.0565
# Epoch 15/25 - Loss: 0.0531
# Epoch 16/25 - Loss: 0.0510
# Epoch 17/25 - Loss: 0.0482
# Epoch 18/25 - Loss: 0.0458
# Epoch 19/25 - Loss: 0.0433
# Epoch 20/25 - Loss: 0.0420
# Epoch 21/25 - Loss: 0.0402
# Epoch 22/25 - Loss: 0.0383
# Epoch 23/25 - Loss: 0.0369
# Epoch 24/25 - Loss: 0.0351
# Epoch 25/25 - Loss: 0.0332
# 📊 Evaluation Results - Acc: 0.925, Prec: 0.713, Rec: 0.770, F1: 0.740
#      ➤ F1-score: 0.740, Accuracy: 0.925
#   ▶ Training for Feature: nasal
# Epoch 1/25 - Loss: 0.5124
# Epoch 2/25 - Loss: 0.2604
# Epoch 3/25 - Loss: 0.1592
# Epoch 4/25 - Loss: 0.0925
# Epoch 5/25 - Loss: 0.0650
# Epoch 6/25 - Loss: 0.0514
# Epoch 7/25 - Loss: 0.0432
# Epoch 8/25 - Loss: 0.0385
# Epoch 9/25 - Loss: 0.0354
# Epoch 10/25 - Loss: 0.0328
# Epoch 11/25 - Loss: 0.0308
# Epoch 12/25 - Loss: 0.0284
# Epoch 13/25 - Loss: 0.0267
# Epoch 14/25 - Loss: 0.0250
# Epoch 15/25 - Loss: 0.0236
# Epoch 16/25 - Loss: 0.0221
# Epoch 17/25 - Loss: 0.0207
# Epoch 18/25 - Loss: 0.0197
# Epoch 19/25 - Loss: 0.0186
# Epoch 20/25 - Loss: 0.0177
# Epoch 21/25 - Loss: 0.0169
# Epoch 22/25 - Loss: 0.0158
# Epoch 23/25 - Loss: 0.0151
# Epoch 24/25 - Loss: 0.0142
# Epoch 25/25 - Loss: 0.0134
# 📊 Evaluation Results - Acc: 0.968, Prec: 0.719, Rec: 0.742, F1: 0.730
#      ➤ F1-score: 0.730, Accuracy: 0.968
#
# 🔍 Processing Layer 3
#   ▶ Training for Feature: voiced
# Epoch 1/25 - Loss: 0.5814
# Epoch 2/25 - Loss: 0.3509
# Epoch 3/25 - Loss: 0.2107
# Epoch 4/25 - Loss: 0.1516
# Epoch 5/25 - Loss: 0.1250
# Epoch 6/25 - Loss: 0.1114
# Epoch 7/25 - Loss: 0.1014
# Epoch 8/25 - Loss: 0.0942
# Epoch 9/25 - Loss: 0.0882
# Epoch 10/25 - Loss: 0.0830
# Epoch 11/25 - Loss: 0.0791
# Epoch 12/25 - Loss: 0.0749
# Epoch 13/25 - Loss: 0.0702
# Epoch 14/25 - Loss: 0.0672
# Epoch 15/25 - Loss: 0.0637
# Epoch 16/25 - Loss: 0.0606
# Epoch 17/25 - Loss: 0.0579
# Epoch 18/25 - Loss: 0.0557
# Epoch 19/25 - Loss: 0.0530
# Epoch 20/25 - Loss: 0.0504
# Epoch 21/25 - Loss: 0.0477
# Epoch 22/25 - Loss: 0.0462
# Epoch 23/25 - Loss: 0.0432
# Epoch 24/25 - Loss: 0.0416
# Epoch 25/25 - Loss: 0.0396
# 📊 Evaluation Results - Acc: 0.871, Prec: 0.856, Rec: 0.913, F1: 0.884
#      ➤ F1-score: 0.884, Accuracy: 0.871
#   ▶ Training for Feature: fricative
# Epoch 1/25 - Loss: 0.5335
# Epoch 2/25 - Loss: 0.2945
# Epoch 3/25 - Loss: 0.1828
# Epoch 4/25 - Loss: 0.1259
# Epoch 5/25 - Loss: 0.0941
# Epoch 6/25 - Loss: 0.0762
# Epoch 7/25 - Loss: 0.0658
# Epoch 8/25 - Loss: 0.0585
# Epoch 9/25 - Loss: 0.0526
# Epoch 10/25 - Loss: 0.0477
# Epoch 11/25 - Loss: 0.0437
# Epoch 12/25 - Loss: 0.0407
# Epoch 13/25 - Loss: 0.0374
# Epoch 14/25 - Loss: 0.0350
# Epoch 15/25 - Loss: 0.0329
# Epoch 16/25 - Loss: 0.0306
# Epoch 17/25 - Loss: 0.0287
# Epoch 18/25 - Loss: 0.0272
# Epoch 19/25 - Loss: 0.0254
# Epoch 20/25 - Loss: 0.0239
# Epoch 21/25 - Loss: 0.0224
# Epoch 22/25 - Loss: 0.0209
# Epoch 23/25 - Loss: 0.0195
# Epoch 24/25 - Loss: 0.0183
# Epoch 25/25 - Loss: 0.0169
# 📊 Evaluation Results - Acc: 0.929, Prec: 0.714, Rec: 0.811, F1: 0.759
#      ➤ F1-score: 0.759, Accuracy: 0.929
#   ▶ Training for Feature: nasal
# Epoch 1/25 - Loss: 0.5385
# Epoch 2/25 - Loss: 0.2719
# Epoch 3/25 - Loss: 0.1358
# Epoch 4/25 - Loss: 0.0725
# Epoch 5/25 - Loss: 0.0485
# Epoch 6/25 - Loss: 0.0398
# Epoch 7/25 - Loss: 0.0341
# Epoch 8/25 - Loss: 0.0307
# Epoch 9/25 - Loss: 0.0278
# Epoch 10/25 - Loss: 0.0258
# Epoch 11/25 - Loss: 0.0236
# Epoch 12/25 - Loss: 0.0216
# Epoch 13/25 - Loss: 0.0198
# Epoch 14/25 - Loss: 0.0185
# Epoch 15/25 - Loss: 0.0172
# Epoch 16/25 - Loss: 0.0161
# Epoch 17/25 - Loss: 0.0148
# Epoch 18/25 - Loss: 0.0137
# Epoch 19/25 - Loss: 0.0129
# Epoch 20/25 - Loss: 0.0119
# Epoch 21/25 - Loss: 0.0111
# Epoch 22/25 - Loss: 0.0102
# Epoch 23/25 - Loss: 0.0096
# Epoch 24/25 - Loss: 0.0090
# Epoch 25/25 - Loss: 0.0083
# 📊 Evaluation Results - Acc: 0.970, Prec: 0.742, Rec: 0.742, F1: 0.742
#      ➤ F1-score: 0.742, Accuracy: 0.970
#
# 🔍 Processing Layer 4
#   ▶ Training for Feature: voiced
# Epoch 1/25 - Loss: 0.5876
# Epoch 2/25 - Loss: 0.3546
# Epoch 3/25 - Loss: 0.2105
# Epoch 4/25 - Loss: 0.1478
# Epoch 5/25 - Loss: 0.1197
# Epoch 6/25 - Loss: 0.1040
# Epoch 7/25 - Loss: 0.0935
# Epoch 8/25 - Loss: 0.0860
# Epoch 9/25 - Loss: 0.0798
# Epoch 10/25 - Loss: 0.0747
# Epoch 11/25 - Loss: 0.0698
# Epoch 12/25 - Loss: 0.0662
# Epoch 13/25 - Loss: 0.0619
# Epoch 14/25 - Loss: 0.0585
# Epoch 15/25 - Loss: 0.0550
# Epoch 16/25 - Loss: 0.0518
# Epoch 17/25 - Loss: 0.0493
# Epoch 18/25 - Loss: 0.0462
# Epoch 19/25 - Loss: 0.0439
# Epoch 20/25 - Loss: 0.0413
# Epoch 21/25 - Loss: 0.0389
# Epoch 22/25 - Loss: 0.0372
# Epoch 23/25 - Loss: 0.0353
# Epoch 24/25 - Loss: 0.0329
# Epoch 25/25 - Loss: 0.0314
# 📊 Evaluation Results - Acc: 0.879, Prec: 0.865, Rec: 0.916, F1: 0.890
#      ➤ F1-score: 0.890, Accuracy: 0.879
#   ▶ Training for Feature: fricative
# Epoch 1/25 - Loss: 0.5653
# Epoch 2/25 - Loss: 0.3336
# Epoch 3/25 - Loss: 0.1891
# Epoch 4/25 - Loss: 0.1177
# Epoch 5/25 - Loss: 0.0846
# Epoch 6/25 - Loss: 0.0672
# Epoch 7/25 - Loss: 0.0577
# Epoch 8/25 - Loss: 0.0506
# Epoch 9/25 - Loss: 0.0455
# Epoch 10/25 - Loss: 0.0419
# Epoch 11/25 - Loss: 0.0384
# Epoch 12/25 - Loss: 0.0352
# Epoch 13/25 - Loss: 0.0327
# Epoch 14/25 - Loss: 0.0301
# Epoch 15/25 - Loss: 0.0282
# Epoch 16/25 - Loss: 0.0260
# Epoch 17/25 - Loss: 0.0241
# Epoch 18/25 - Loss: 0.0225
# Epoch 19/25 - Loss: 0.0207
# Epoch 20/25 - Loss: 0.0191
# Epoch 21/25 - Loss: 0.0176
# Epoch 22/25 - Loss: 0.0162
# Epoch 23/25 - Loss: 0.0149
# Epoch 24/25 - Loss: 0.0138
# Epoch 25/25 - Loss: 0.0127
# 📊 Evaluation Results - Acc: 0.925, Prec: 0.718, Rec: 0.757, F1: 0.737
#      ➤ F1-score: 0.737, Accuracy: 0.925
#   ▶ Training for Feature: nasal
# Epoch 1/25 - Loss: 0.5687
# Epoch 2/25 - Loss: 0.3033
# Epoch 3/25 - Loss: 0.1456
# Epoch 4/25 - Loss: 0.0751
# Epoch 5/25 - Loss: 0.0482
# Epoch 6/25 - Loss: 0.0388
# Epoch 7/25 - Loss: 0.0336
# Epoch 8/25 - Loss: 0.0305
# Epoch 9/25 - Loss: 0.0276
# Epoch 10/25 - Loss: 0.0254
# Epoch 11/25 - Loss: 0.0235
# Epoch 12/25 - Loss: 0.0220
# Epoch 13/25 - Loss: 0.0205
# Epoch 14/25 - Loss: 0.0195
# Epoch 15/25 - Loss: 0.0183
# Epoch 16/25 - Loss: 0.0170
# Epoch 17/25 - Loss: 0.0160
# Epoch 18/25 - Loss: 0.0151
# Epoch 19/25 - Loss: 0.0141
# Epoch 20/25 - Loss: 0.0133
# Epoch 21/25 - Loss: 0.0125
# Epoch 22/25 - Loss: 0.0117
# Epoch 23/25 - Loss: 0.0109
# Epoch 24/25 - Loss: 0.0102
# Epoch 25/25 - Loss: 0.0096
# 📊 Evaluation Results - Acc: 0.966, Prec: 0.710, Rec: 0.710, F1: 0.710
#      ➤ F1-score: 0.710, Accuracy: 0.966
#
# 🔍 Processing Layer 5
#   ▶ Training for Feature: voiced
# Epoch 1/25 - Loss: 0.5884
# Epoch 2/25 - Loss: 0.3553
# Epoch 3/25 - Loss: 0.2047
# Epoch 4/25 - Loss: 0.1348
# Epoch 5/25 - Loss: 0.1016
# Epoch 6/25 - Loss: 0.0849
# Epoch 7/25 - Loss: 0.0751
# Epoch 8/25 - Loss: 0.0681
# Epoch 9/25 - Loss: 0.0623
# Epoch 10/25 - Loss: 0.0581
# Epoch 11/25 - Loss: 0.0542
# Epoch 12/25 - Loss: 0.0506
# Epoch 13/25 - Loss: 0.0473
# Epoch 14/25 - Loss: 0.0448
# Epoch 15/25 - Loss: 0.0426
# Epoch 16/25 - Loss: 0.0403
# Epoch 17/25 - Loss: 0.0380
# Epoch 18/25 - Loss: 0.0358
# Epoch 19/25 - Loss: 0.0338
# Epoch 20/25 - Loss: 0.0320
# Epoch 21/25 - Loss: 0.0309
# Epoch 22/25 - Loss: 0.0289
# Epoch 23/25 - Loss: 0.0274
# Epoch 24/25 - Loss: 0.0258
# Epoch 25/25 - Loss: 0.0243
# 📊 Evaluation Results - Acc: 0.884, Prec: 0.874, Rec: 0.916, F1: 0.895
#      ➤ F1-score: 0.895, Accuracy: 0.884
#   ▶ Training for Feature: fricative
# Epoch 1/25 - Loss: 0.5713
# Epoch 2/25 - Loss: 0.3292
# Epoch 3/25 - Loss: 0.1914
# Epoch 4/25 - Loss: 0.1138
# Epoch 5/25 - Loss: 0.0774
# Epoch 6/25 - Loss: 0.0573
# Epoch 7/25 - Loss: 0.0461
# Epoch 8/25 - Loss: 0.0394
# Epoch 9/25 - Loss: 0.0350
# Epoch 10/25 - Loss: 0.0313
# Epoch 11/25 - Loss: 0.0283
# Epoch 12/25 - Loss: 0.0256
# Epoch 13/25 - Loss: 0.0234
# Epoch 14/25 - Loss: 0.0216
# Epoch 15/25 - Loss: 0.0197
# Epoch 16/25 - Loss: 0.0180
# Epoch 17/25 - Loss: 0.0167
# Epoch 18/25 - Loss: 0.0152
# Epoch 19/25 - Loss: 0.0140
# Epoch 20/25 - Loss: 0.0129
# Epoch 21/25 - Loss: 0.0118
# Epoch 22/25 - Loss: 0.0110
# Epoch 23/25 - Loss: 0.0102
# Epoch 24/25 - Loss: 0.0093
# Epoch 25/25 - Loss: 0.0087
# 📊 Evaluation Results - Acc: 0.946, Prec: 0.778, Rec: 0.851, F1: 0.813
#      ➤ F1-score: 0.813, Accuracy: 0.946
#   ▶ Training for Feature: nasal
# Epoch 1/25 - Loss: 0.5427
# Epoch 2/25 - Loss: 0.2869
# Epoch 3/25 - Loss: 0.1557
# Epoch 4/25 - Loss: 0.0840
# Epoch 5/25 - Loss: 0.0520
# Epoch 6/25 - Loss: 0.0388
# Epoch 7/25 - Loss: 0.0314
# Epoch 8/25 - Loss: 0.0270
# Epoch 9/25 - Loss: 0.0244
# Epoch 10/25 - Loss: 0.0224
# Epoch 11/25 - Loss: 0.0199
# Epoch 12/25 - Loss: 0.0182
# Epoch 13/25 - Loss: 0.0169
# Epoch 14/25 - Loss: 0.0156
# Epoch 15/25 - Loss: 0.0143
# Epoch 16/25 - Loss: 0.0132
# Epoch 17/25 - Loss: 0.0121
# Epoch 18/25 - Loss: 0.0112
# Epoch 19/25 - Loss: 0.0104
# Epoch 20/25 - Loss: 0.0095
# Epoch 21/25 - Loss: 0.0089
# Epoch 22/25 - Loss: 0.0081
# Epoch 23/25 - Loss: 0.0074
# Epoch 24/25 - Loss: 0.0069
# Epoch 25/25 - Loss: 0.0064
# 📊 Evaluation Results - Acc: 0.968, Prec: 0.750, Rec: 0.677, F1: 0.712
#      ➤ F1-score: 0.712, Accuracy: 0.968
#
# 🔍 Processing Layer 6
#   ▶ Training for Feature: voiced
# Epoch 1/25 - Loss: 0.5808
# Epoch 2/25 - Loss: 0.3529
# Epoch 3/25 - Loss: 0.1978
# Epoch 4/25 - Loss: 0.1253
# Epoch 5/25 - Loss: 0.0907
# Epoch 6/25 - Loss: 0.0752
# Epoch 7/25 - Loss: 0.0659
# Epoch 8/25 - Loss: 0.0596
# Epoch 9/25 - Loss: 0.0542
# Epoch 10/25 - Loss: 0.0502
# Epoch 11/25 - Loss: 0.0463
# Epoch 12/25 - Loss: 0.0433
# Epoch 13/25 - Loss: 0.0400
# Epoch 14/25 - Loss: 0.0374
# Epoch 15/25 - Loss: 0.0351
# Epoch 16/25 - Loss: 0.0328
# Epoch 17/25 - Loss: 0.0312
# Epoch 18/25 - Loss: 0.0293
# Epoch 19/25 - Loss: 0.0271
# Epoch 20/25 - Loss: 0.0259
# Epoch 21/25 - Loss: 0.0241
# Epoch 22/25 - Loss: 0.0225
# Epoch 23/25 - Loss: 0.0213
# Epoch 24/25 - Loss: 0.0198
# Epoch 25/25 - Loss: 0.0187
# 📊 Evaluation Results - Acc: 0.910, Prec: 0.897, Rec: 0.941, F1: 0.918
#      ➤ F1-score: 0.918, Accuracy: 0.910
#   ▶ Training for Feature: fricative
# Epoch 1/25 - Loss: 0.5710
# Epoch 2/25 - Loss: 0.3309
# Epoch 3/25 - Loss: 0.1950
# Epoch 4/25 - Loss: 0.1169
# Epoch 5/25 - Loss: 0.0788
# Epoch 6/25 - Loss: 0.0573
# Epoch 7/25 - Loss: 0.0460
# Epoch 8/25 - Loss: 0.0392
# Epoch 9/25 - Loss: 0.0348
# Epoch 10/25 - Loss: 0.0311
# Epoch 11/25 - Loss: 0.0279
# Epoch 12/25 - Loss: 0.0260
# Epoch 13/25 - Loss: 0.0236
# Epoch 14/25 - Loss: 0.0214
# Epoch 15/25 - Loss: 0.0199
# Epoch 16/25 - Loss: 0.0183
# Epoch 17/25 - Loss: 0.0168
# Epoch 18/25 - Loss: 0.0154
# Epoch 19/25 - Loss: 0.0141
# Epoch 20/25 - Loss: 0.0130
# Epoch 21/25 - Loss: 0.0120
# Epoch 22/25 - Loss: 0.0110
# Epoch 23/25 - Loss: 0.0102
# Epoch 24/25 - Loss: 0.0093
# Epoch 25/25 - Loss: 0.0086
# 📊 Evaluation Results - Acc: 0.948, Prec: 0.803, Rec: 0.824, F1: 0.813
#      ➤ F1-score: 0.813, Accuracy: 0.948
#   ▶ Training for Feature: nasal
# Epoch 1/25 - Loss: 0.5198
# Epoch 2/25 - Loss: 0.2761
# Epoch 3/25 - Loss: 0.1526
# Epoch 4/25 - Loss: 0.0817
# Epoch 5/25 - Loss: 0.0500
# Epoch 6/25 - Loss: 0.0362
# Epoch 7/25 - Loss: 0.0288
# Epoch 8/25 - Loss: 0.0244
# Epoch 9/25 - Loss: 0.0217
# Epoch 10/25 - Loss: 0.0192
# Epoch 11/25 - Loss: 0.0173
# Epoch 12/25 - Loss: 0.0158
# Epoch 13/25 - Loss: 0.0142
# Epoch 14/25 - Loss: 0.0130
# Epoch 15/25 - Loss: 0.0118
# Epoch 16/25 - Loss: 0.0108
# Epoch 17/25 - Loss: 0.0100
# Epoch 18/25 - Loss: 0.0091
# Epoch 19/25 - Loss: 0.0082
# Epoch 20/25 - Loss: 0.0076
# Epoch 21/25 - Loss: 0.0069
# Epoch 22/25 - Loss: 0.0063
# Epoch 23/25 - Loss: 0.0058
# Epoch 24/25 - Loss: 0.0052
# Epoch 25/25 - Loss: 0.0048
# 📊 Evaluation Results - Acc: 0.972, Prec: 0.786, Rec: 0.710, F1: 0.746
#      ➤ F1-score: 0.746, Accuracy: 0.972
#
# 🔍 Processing Layer 7
#   ▶ Training for Feature: voiced
# Epoch 1/25 - Loss: 0.5814
# Epoch 2/25 - Loss: 0.3555
# Epoch 3/25 - Loss: 0.2037
# Epoch 4/25 - Loss: 0.1273
# Epoch 5/25 - Loss: 0.0922
# Epoch 6/25 - Loss: 0.0744
# Epoch 7/25 - Loss: 0.0645
# Epoch 8/25 - Loss: 0.0573
# Epoch 9/25 - Loss: 0.0518
# Epoch 10/25 - Loss: 0.0477
# Epoch 11/25 - Loss: 0.0440
# Epoch 12/25 - Loss: 0.0409
# Epoch 13/25 - Loss: 0.0384
# Epoch 14/25 - Loss: 0.0360
# Epoch 15/25 - Loss: 0.0334
# Epoch 16/25 - Loss: 0.0313
# Epoch 17/25 - Loss: 0.0293
# Epoch 18/25 - Loss: 0.0270
# Epoch 19/25 - Loss: 0.0256
# Epoch 20/25 - Loss: 0.0238
# Epoch 21/25 - Loss: 0.0225
# Epoch 22/25 - Loss: 0.0213
# Epoch 23/25 - Loss: 0.0199
# Epoch 24/25 - Loss: 0.0186
# Epoch 25/25 - Loss: 0.0176
# 📊 Evaluation Results - Acc: 0.897, Prec: 0.882, Rec: 0.934, F1: 0.907
#      ➤ F1-score: 0.907, Accuracy: 0.897
#   ▶ Training for Feature: fricative
# Epoch 1/25 - Loss: 0.5780
# Epoch 2/25 - Loss: 0.3457
# Epoch 3/25 - Loss: 0.1989
# Epoch 4/25 - Loss: 0.1156
# Epoch 5/25 - Loss: 0.0753
# Epoch 6/25 - Loss: 0.0542
# Epoch 7/25 - Loss: 0.0435
# Epoch 8/25 - Loss: 0.0372
# Epoch 9/25 - Loss: 0.0326
# Epoch 10/25 - Loss: 0.0292
# Epoch 11/25 - Loss: 0.0265
# Epoch 12/25 - Loss: 0.0238
# Epoch 13/25 - Loss: 0.0217
# Epoch 14/25 - Loss: 0.0198
# Epoch 15/25 - Loss: 0.0180
# Epoch 16/25 - Loss: 0.0162
# Epoch 17/25 - Loss: 0.0147
# Epoch 18/25 - Loss: 0.0135
# Epoch 19/25 - Loss: 0.0123
# Epoch 20/25 - Loss: 0.0111
# Epoch 21/25 - Loss: 0.0102
# Epoch 22/25 - Loss: 0.0093
# Epoch 23/25 - Loss: 0.0085
# Epoch 24/25 - Loss: 0.0077
# Epoch 25/25 - Loss: 0.0070
# 📊 Evaluation Results - Acc: 0.944, Prec: 0.768, Rec: 0.851, F1: 0.808
#      ➤ F1-score: 0.808, Accuracy: 0.944
#   ▶ Training for Feature: nasal
# Epoch 1/25 - Loss: 0.5301
# Epoch 2/25 - Loss: 0.2933
# Epoch 3/25 - Loss: 0.1598
# Epoch 4/25 - Loss: 0.0837
# Epoch 5/25 - Loss: 0.0511
# Epoch 6/25 - Loss: 0.0368
# Epoch 7/25 - Loss: 0.0290
# Epoch 8/25 - Loss: 0.0243
# Epoch 9/25 - Loss: 0.0212
# Epoch 10/25 - Loss: 0.0186
# Epoch 11/25 - Loss: 0.0166
# Epoch 12/25 - Loss: 0.0149
# Epoch 13/25 - Loss: 0.0135
# Epoch 14/25 - Loss: 0.0121
# Epoch 15/25 - Loss: 0.0110
# Epoch 16/25 - Loss: 0.0099
# Epoch 17/25 - Loss: 0.0091
# Epoch 18/25 - Loss: 0.0083
# Epoch 19/25 - Loss: 0.0075
# Epoch 20/25 - Loss: 0.0068
# Epoch 21/25 - Loss: 0.0062
# Epoch 22/25 - Loss: 0.0057
# Epoch 23/25 - Loss: 0.0052
# Epoch 24/25 - Loss: 0.0047
# Epoch 25/25 - Loss: 0.0043
# 📊 Evaluation Results - Acc: 0.968, Prec: 0.750, Rec: 0.677, F1: 0.712
#      ➤ F1-score: 0.712, Accuracy: 0.968
#
# 🔍 Processing Layer 8
#   ▶ Training for Feature: voiced
# Epoch 1/25 - Loss: 0.5972
# Epoch 2/25 - Loss: 0.3874
# Epoch 3/25 - Loss: 0.2288
# Epoch 4/25 - Loss: 0.1410
# Epoch 5/25 - Loss: 0.0980
# Epoch 6/25 - Loss: 0.0761
# Epoch 7/25 - Loss: 0.0647
# Epoch 8/25 - Loss: 0.0562
# Epoch 9/25 - Loss: 0.0508
# Epoch 10/25 - Loss: 0.0459
# Epoch 11/25 - Loss: 0.0421
# Epoch 12/25 - Loss: 0.0391
# Epoch 13/25 - Loss: 0.0361
# Epoch 14/25 - Loss: 0.0336
# Epoch 15/25 - Loss: 0.0316
# Epoch 16/25 - Loss: 0.0301
# Epoch 17/25 - Loss: 0.0281
# Epoch 18/25 - Loss: 0.0260
# Epoch 19/25 - Loss: 0.0242
# Epoch 20/25 - Loss: 0.0228
# Epoch 21/25 - Loss: 0.0219
# Epoch 22/25 - Loss: 0.0201
# Epoch 23/25 - Loss: 0.0190
# Epoch 24/25 - Loss: 0.0180
# Epoch 25/25 - Loss: 0.0170
# 📊 Evaluation Results - Acc: 0.910, Prec: 0.905, Rec: 0.930, F1: 0.918
#      ➤ F1-score: 0.918, Accuracy: 0.910
#   ▶ Training for Feature: fricative
# Epoch 1/25 - Loss: 0.5712
# Epoch 2/25 - Loss: 0.3517
# Epoch 3/25 - Loss: 0.2153
# Epoch 4/25 - Loss: 0.1326
# Epoch 5/25 - Loss: 0.0880
# Epoch 6/25 - Loss: 0.0614
# Epoch 7/25 - Loss: 0.0483
# Epoch 8/25 - Loss: 0.0406
# Epoch 9/25 - Loss: 0.0356
# Epoch 10/25 - Loss: 0.0319
# Epoch 11/25 - Loss: 0.0288
# Epoch 12/25 - Loss: 0.0270
# Epoch 13/25 - Loss: 0.0245
# Epoch 14/25 - Loss: 0.0226
# Epoch 15/25 - Loss: 0.0208
# Epoch 16/25 - Loss: 0.0193
# Epoch 17/25 - Loss: 0.0177
# Epoch 18/25 - Loss: 0.0164
# Epoch 19/25 - Loss: 0.0151
# Epoch 20/25 - Loss: 0.0142
# Epoch 21/25 - Loss: 0.0131
# Epoch 22/25 - Loss: 0.0119
# Epoch 23/25 - Loss: 0.0112
# Epoch 24/25 - Loss: 0.0104
# Epoch 25/25 - Loss: 0.0097
# 📊 Evaluation Results - Acc: 0.957, Prec: 0.840, Rec: 0.851, F1: 0.846
#      ➤ F1-score: 0.846, Accuracy: 0.957
#   ▶ Training for Feature: nasal
# Epoch 1/25 - Loss: 0.5864
# Epoch 2/25 - Loss: 0.3468
# Epoch 3/25 - Loss: 0.2094
# Epoch 4/25 - Loss: 0.1195
# Epoch 5/25 - Loss: 0.0701
# Epoch 6/25 - Loss: 0.0479
# Epoch 7/25 - Loss: 0.0360
# Epoch 8/25 - Loss: 0.0294
# Epoch 9/25 - Loss: 0.0250
# Epoch 10/25 - Loss: 0.0220
# Epoch 11/25 - Loss: 0.0193
# Epoch 12/25 - Loss: 0.0172
# Epoch 13/25 - Loss: 0.0156
# Epoch 14/25 - Loss: 0.0141
# Epoch 15/25 - Loss: 0.0127
# Epoch 16/25 - Loss: 0.0115
# Epoch 17/25 - Loss: 0.0104
# Epoch 18/25 - Loss: 0.0094
# Epoch 19/25 - Loss: 0.0086
# Epoch 20/25 - Loss: 0.0078
# Epoch 21/25 - Loss: 0.0070
# Epoch 22/25 - Loss: 0.0064
# Epoch 23/25 - Loss: 0.0058
# Epoch 24/25 - Loss: 0.0053
# Epoch 25/25 - Loss: 0.0049
# 📊 Evaluation Results - Acc: 0.970, Prec: 0.778, Rec: 0.677, F1: 0.724
#      ➤ F1-score: 0.724, Accuracy: 0.970
#
# 🔍 Processing Layer 9
#   ▶ Training for Feature: voiced
# Epoch 1/25 - Loss: 0.5938
# Epoch 2/25 - Loss: 0.3892
# Epoch 3/25 - Loss: 0.2415
# Epoch 4/25 - Loss: 0.1553
# Epoch 5/25 - Loss: 0.1094
# Epoch 6/25 - Loss: 0.0841
# Epoch 7/25 - Loss: 0.0699
# Epoch 8/25 - Loss: 0.0611
# Epoch 9/25 - Loss: 0.0542
# Epoch 10/25 - Loss: 0.0487
# Epoch 11/25 - Loss: 0.0451
# Epoch 12/25 - Loss: 0.0414
# Epoch 13/25 - Loss: 0.0384
# Epoch 14/25 - Loss: 0.0359
# Epoch 15/25 - Loss: 0.0335
# Epoch 16/25 - Loss: 0.0316
# Epoch 17/25 - Loss: 0.0293
# Epoch 18/25 - Loss: 0.0276
# Epoch 19/25 - Loss: 0.0262
# Epoch 20/25 - Loss: 0.0244
# Epoch 21/25 - Loss: 0.0231
# Epoch 22/25 - Loss: 0.0216
# Epoch 23/25 - Loss: 0.0203
# Epoch 24/25 - Loss: 0.0191
# Epoch 25/25 - Loss: 0.0181
# 📊 Evaluation Results - Acc: 0.888, Prec: 0.880, Rec: 0.916, F1: 0.898
#      ➤ F1-score: 0.898, Accuracy: 0.888
#   ▶ Training for Feature: fricative
# Epoch 1/25 - Loss: 0.5558
# Epoch 2/25 - Loss: 0.3302
# Epoch 3/25 - Loss: 0.2038
# Epoch 4/25 - Loss: 0.1329
# Epoch 5/25 - Loss: 0.0915
# Epoch 6/25 - Loss: 0.0665
# Epoch 7/25 - Loss: 0.0518
# Epoch 8/25 - Loss: 0.0435
# Epoch 9/25 - Loss: 0.0376
# Epoch 10/25 - Loss: 0.0336
# Epoch 11/25 - Loss: 0.0301
# Epoch 12/25 - Loss: 0.0272
# Epoch 13/25 - Loss: 0.0247
# Epoch 14/25 - Loss: 0.0226
# Epoch 15/25 - Loss: 0.0207
# Epoch 16/25 - Loss: 0.0190
# Epoch 17/25 - Loss: 0.0176
# Epoch 18/25 - Loss: 0.0161
# Epoch 19/25 - Loss: 0.0149
# Epoch 20/25 - Loss: 0.0139
# Epoch 21/25 - Loss: 0.0127
# Epoch 22/25 - Loss: 0.0119
# Epoch 23/25 - Loss: 0.0110
# Epoch 24/25 - Loss: 0.0102
# Epoch 25/25 - Loss: 0.0096
# 📊 Evaluation Results - Acc: 0.948, Prec: 0.819, Rec: 0.797, F1: 0.808
#      ➤ F1-score: 0.808, Accuracy: 0.948
#   ▶ Training for Feature: nasal
# Epoch 1/25 - Loss: 0.5381
# Epoch 2/25 - Loss: 0.3160
# Epoch 3/25 - Loss: 0.1924
# Epoch 4/25 - Loss: 0.1130
# Epoch 5/25 - Loss: 0.0682
# Epoch 6/25 - Loss: 0.0467
# Epoch 7/25 - Loss: 0.0345
# Epoch 8/25 - Loss: 0.0275
# Epoch 9/25 - Loss: 0.0228
# Epoch 10/25 - Loss: 0.0198
# Epoch 11/25 - Loss: 0.0170
# Epoch 12/25 - Loss: 0.0153
# Epoch 13/25 - Loss: 0.0136
# Epoch 14/25 - Loss: 0.0120
# Epoch 15/25 - Loss: 0.0108
# Epoch 16/25 - Loss: 0.0097
# Epoch 17/25 - Loss: 0.0089
# Epoch 18/25 - Loss: 0.0079
# Epoch 19/25 - Loss: 0.0072
# Epoch 20/25 - Loss: 0.0065
# Epoch 21/25 - Loss: 0.0059
# Epoch 22/25 - Loss: 0.0054
# Epoch 23/25 - Loss: 0.0050
# Epoch 24/25 - Loss: 0.0046
# Epoch 25/25 - Loss: 0.0042
# 📊 Evaluation Results - Acc: 0.974, Prec: 0.815, Rec: 0.710, F1: 0.759
#      ➤ F1-score: 0.759, Accuracy: 0.974
#
# 🔍 Processing Layer 10
#   ▶ Training for Feature: voiced
# Epoch 1/25 - Loss: 0.5973
# Epoch 2/25 - Loss: 0.3685
# Epoch 3/25 - Loss: 0.2105
# Epoch 4/25 - Loss: 0.1339
# Epoch 5/25 - Loss: 0.0965
# Epoch 6/25 - Loss: 0.0771
# Epoch 7/25 - Loss: 0.0663
# Epoch 8/25 - Loss: 0.0583
# Epoch 9/25 - Loss: 0.0526
# Epoch 10/25 - Loss: 0.0485
# Epoch 11/25 - Loss: 0.0445
# Epoch 12/25 - Loss: 0.0415
# Epoch 13/25 - Loss: 0.0384
# Epoch 14/25 - Loss: 0.0365
# Epoch 15/25 - Loss: 0.0340
# Epoch 16/25 - Loss: 0.0323
# Epoch 17/25 - Loss: 0.0302
# Epoch 18/25 - Loss: 0.0287
# Epoch 19/25 - Loss: 0.0274
# Epoch 20/25 - Loss: 0.0259
# Epoch 21/25 - Loss: 0.0245
# Epoch 22/25 - Loss: 0.0236
# Epoch 23/25 - Loss: 0.0226
# Epoch 24/25 - Loss: 0.0212
# Epoch 25/25 - Loss: 0.0202
# 📊 Evaluation Results - Acc: 0.901, Prec: 0.895, Rec: 0.923, F1: 0.909
#      ➤ F1-score: 0.909, Accuracy: 0.901
#   ▶ Training for Feature: fricative
# Epoch 1/25 - Loss: 0.5734
# Epoch 2/25 - Loss: 0.3357
# Epoch 3/25 - Loss: 0.1993
# Epoch 4/25 - Loss: 0.1235
# Epoch 5/25 - Loss: 0.0825
# Epoch 6/25 - Loss: 0.0578
# Epoch 7/25 - Loss: 0.0457
# Epoch 8/25 - Loss: 0.0378
# Epoch 9/25 - Loss: 0.0328
# Epoch 10/25 - Loss: 0.0291
# Epoch 11/25 - Loss: 0.0263
# Epoch 12/25 - Loss: 0.0242
# Epoch 13/25 - Loss: 0.0218
# Epoch 14/25 - Loss: 0.0201
# Epoch 15/25 - Loss: 0.0185
# Epoch 16/25 - Loss: 0.0172
# Epoch 17/25 - Loss: 0.0161
# Epoch 18/25 - Loss: 0.0148
# Epoch 19/25 - Loss: 0.0138
# Epoch 20/25 - Loss: 0.0129
# Epoch 21/25 - Loss: 0.0122
# Epoch 22/25 - Loss: 0.0113
# Epoch 23/25 - Loss: 0.0106
# Epoch 24/25 - Loss: 0.0100
# Epoch 25/25 - Loss: 0.0093
# 📊 Evaluation Results - Acc: 0.950, Prec: 0.841, Rec: 0.784, F1: 0.811
#      ➤ F1-score: 0.811, Accuracy: 0.950
#   ▶ Training for Feature: nasal
# Epoch 1/25 - Loss: 0.5266
# Epoch 2/25 - Loss: 0.2850
# Epoch 3/25 - Loss: 0.1611
# Epoch 4/25 - Loss: 0.0918
# Epoch 5/25 - Loss: 0.0566
# Epoch 6/25 - Loss: 0.0400
# Epoch 7/25 - Loss: 0.0310
# Epoch 8/25 - Loss: 0.0252
# Epoch 9/25 - Loss: 0.0219
# Epoch 10/25 - Loss: 0.0193
# Epoch 11/25 - Loss: 0.0173
# Epoch 12/25 - Loss: 0.0156
# Epoch 13/25 - Loss: 0.0142
# Epoch 14/25 - Loss: 0.0131
# Epoch 15/25 - Loss: 0.0119
# Epoch 16/25 - Loss: 0.0109
# Epoch 17/25 - Loss: 0.0101
# Epoch 18/25 - Loss: 0.0094
# Epoch 19/25 - Loss: 0.0087
# Epoch 20/25 - Loss: 0.0080
# Epoch 21/25 - Loss: 0.0075
# Epoch 22/25 - Loss: 0.0070
# Epoch 23/25 - Loss: 0.0064
# Epoch 24/25 - Loss: 0.0060
# Epoch 25/25 - Loss: 0.0056
# 📊 Evaluation Results - Acc: 0.970, Prec: 0.759, Rec: 0.710, F1: 0.733
#      ➤ F1-score: 0.733, Accuracy: 0.970
#
# 🔍 Processing Layer 11
#   ▶ Training for Feature: voiced
# Epoch 1/25 - Loss: 0.5900
# Epoch 2/25 - Loss: 0.3575
# Epoch 3/25 - Loss: 0.1951
# Epoch 4/25 - Loss: 0.1160
# Epoch 5/25 - Loss: 0.0808
# Epoch 6/25 - Loss: 0.0647
# Epoch 7/25 - Loss: 0.0552
# Epoch 8/25 - Loss: 0.0490
# Epoch 9/25 - Loss: 0.0443
# Epoch 10/25 - Loss: 0.0407
# Epoch 11/25 - Loss: 0.0374
# Epoch 12/25 - Loss: 0.0350
# Epoch 13/25 - Loss: 0.0323
# Epoch 14/25 - Loss: 0.0303
# Epoch 15/25 - Loss: 0.0282
# Epoch 16/25 - Loss: 0.0266
# Epoch 17/25 - Loss: 0.0249
# Epoch 18/25 - Loss: 0.0236
# Epoch 19/25 - Loss: 0.0220
# Epoch 20/25 - Loss: 0.0208
# Epoch 21/25 - Loss: 0.0198
# Epoch 22/25 - Loss: 0.0189
# Epoch 23/25 - Loss: 0.0175
# Epoch 24/25 - Loss: 0.0167
# Epoch 25/25 - Loss: 0.0157
# 📊 Evaluation Results - Acc: 0.890, Prec: 0.890, Rec: 0.906, F1: 0.898
#      ➤ F1-score: 0.898, Accuracy: 0.890
#   ▶ Training for Feature: fricative
# Epoch 1/25 - Loss: 0.5631
# Epoch 2/25 - Loss: 0.3339
# Epoch 3/25 - Loss: 0.1924
# Epoch 4/25 - Loss: 0.1138
# Epoch 5/25 - Loss: 0.0721
# Epoch 6/25 - Loss: 0.0493
# Epoch 7/25 - Loss: 0.0374
# Epoch 8/25 - Loss: 0.0307
# Epoch 9/25 - Loss: 0.0264
# Epoch 10/25 - Loss: 0.0235
# Epoch 11/25 - Loss: 0.0210
# Epoch 12/25 - Loss: 0.0191
# Epoch 13/25 - Loss: 0.0173
# Epoch 14/25 - Loss: 0.0160
# Epoch 15/25 - Loss: 0.0148
# Epoch 16/25 - Loss: 0.0135
# Epoch 17/25 - Loss: 0.0124
# Epoch 18/25 - Loss: 0.0117
# Epoch 19/25 - Loss: 0.0107
# Epoch 20/25 - Loss: 0.0098
# Epoch 21/25 - Loss: 0.0094
# Epoch 22/25 - Loss: 0.0086
# Epoch 23/25 - Loss: 0.0078
# Epoch 24/25 - Loss: 0.0073
# Epoch 25/25 - Loss: 0.0069
# 📊 Evaluation Results - Acc: 0.951, Prec: 0.824, Rec: 0.824, F1: 0.824
#      ➤ F1-score: 0.824, Accuracy: 0.951
#   ▶ Training for Feature: nasal
# Epoch 1/25 - Loss: 0.5646
# Epoch 2/25 - Loss: 0.3125
# Epoch 3/25 - Loss: 0.1729
# Epoch 4/25 - Loss: 0.0971
# Epoch 5/25 - Loss: 0.0583
# Epoch 6/25 - Loss: 0.0394
# Epoch 7/25 - Loss: 0.0293
# Epoch 8/25 - Loss: 0.0235
# Epoch 9/25 - Loss: 0.0198
# Epoch 10/25 - Loss: 0.0171
# Epoch 11/25 - Loss: 0.0154
# Epoch 12/25 - Loss: 0.0137
# Epoch 13/25 - Loss: 0.0123
# Epoch 14/25 - Loss: 0.0112
# Epoch 15/25 - Loss: 0.0101
# Epoch 16/25 - Loss: 0.0092
# Epoch 17/25 - Loss: 0.0083
# Epoch 18/25 - Loss: 0.0076
# Epoch 19/25 - Loss: 0.0070
# Epoch 20/25 - Loss: 0.0065
# Epoch 21/25 - Loss: 0.0059
# Epoch 22/25 - Loss: 0.0055
# Epoch 23/25 - Loss: 0.0050
# Epoch 24/25 - Loss: 0.0046
# Epoch 25/25 - Loss: 0.0044
# 📊 Evaluation Results - Acc: 0.970, Prec: 0.759, Rec: 0.710, F1: 0.733
#      ➤ F1-score: 0.733, Accuracy: 0.970
#
# 🔍 Processing Layer 12
#   ▶ Training for Feature: voiced
# Epoch 1/25 - Loss: 0.5636
# Epoch 2/25 - Loss: 0.3165
# Epoch 3/25 - Loss: 0.1703
# Epoch 4/25 - Loss: 0.1086
# Epoch 5/25 - Loss: 0.0845
# Epoch 6/25 - Loss: 0.0715
# Epoch 7/25 - Loss: 0.0630
# Epoch 8/25 - Loss: 0.0577
# Epoch 9/25 - Loss: 0.0522
# Epoch 10/25 - Loss: 0.0483
# Epoch 11/25 - Loss: 0.0452
# Epoch 12/25 - Loss: 0.0429
# Epoch 13/25 - Loss: 0.0400
# Epoch 14/25 - Loss: 0.0369
# Epoch 15/25 - Loss: 0.0348
# Epoch 16/25 - Loss: 0.0327
# Epoch 17/25 - Loss: 0.0299
# Epoch 18/25 - Loss: 0.0285
# Epoch 19/25 - Loss: 0.0266
# Epoch 20/25 - Loss: 0.0257
# Epoch 21/25 - Loss: 0.0241
# Epoch 22/25 - Loss: 0.0222
# Epoch 23/25 - Loss: 0.0211
# Epoch 24/25 - Loss: 0.0203
# Epoch 25/25 - Loss: 0.0188
# 📊 Evaluation Results - Acc: 0.871, Prec: 0.856, Rec: 0.913, F1: 0.884
#      ➤ F1-score: 0.884, Accuracy: 0.871
#   ▶ Training for Feature: fricative
# Epoch 1/25 - Loss: 0.5097
# Epoch 2/25 - Loss: 0.2656
# Epoch 3/25 - Loss: 0.1498
# Epoch 4/25 - Loss: 0.0881
# Epoch 5/25 - Loss: 0.0585
# Epoch 6/25 - Loss: 0.0424
# Epoch 7/25 - Loss: 0.0349
# Epoch 8/25 - Loss: 0.0303
# Epoch 9/25 - Loss: 0.0272
# Epoch 10/25 - Loss: 0.0249
# Epoch 11/25 - Loss: 0.0229
# Epoch 12/25 - Loss: 0.0210
# Epoch 13/25 - Loss: 0.0197
# Epoch 14/25 - Loss: 0.0185
# Epoch 15/25 - Loss: 0.0173
# Epoch 16/25 - Loss: 0.0161
# Epoch 17/25 - Loss: 0.0153
# Epoch 18/25 - Loss: 0.0144
# Epoch 19/25 - Loss: 0.0134
# Epoch 20/25 - Loss: 0.0129
# Epoch 21/25 - Loss: 0.0122
# Epoch 22/25 - Loss: 0.0116
# Epoch 23/25 - Loss: 0.0109
# Epoch 24/25 - Loss: 0.0100
# Epoch 25/25 - Loss: 0.0096
# 📊 Evaluation Results - Acc: 0.957, Prec: 0.831, Rec: 0.865, F1: 0.848
#      ➤ F1-score: 0.848, Accuracy: 0.957
#   ▶ Training for Feature: nasal
# Epoch 1/25 - Loss: 0.4713
# Epoch 2/25 - Loss: 0.2110
# Epoch 3/25 - Loss: 0.1138
# Epoch 4/25 - Loss: 0.0589
# Epoch 5/25 - Loss: 0.0404
# Epoch 6/25 - Loss: 0.0314
# Epoch 7/25 - Loss: 0.0261
# Epoch 8/25 - Loss: 0.0225
# Epoch 9/25 - Loss: 0.0200
# Epoch 10/25 - Loss: 0.0178
# Epoch 11/25 - Loss: 0.0162
# Epoch 12/25 - Loss: 0.0147
# Epoch 13/25 - Loss: 0.0135
# Epoch 14/25 - Loss: 0.0121
# Epoch 15/25 - Loss: 0.0113
# Epoch 16/25 - Loss: 0.0104
# Epoch 17/25 - Loss: 0.0096
# Epoch 18/25 - Loss: 0.0089
# Epoch 19/25 - Loss: 0.0082
# Epoch 20/25 - Loss: 0.0077
# Epoch 21/25 - Loss: 0.0071
# Epoch 22/25 - Loss: 0.0065
# Epoch 23/25 - Loss: 0.0060
# Epoch 24/25 - Loss: 0.0056
# Epoch 25/25 - Loss: 0.0052
# 📊 Evaluation Results - Acc: 0.970, Prec: 0.759, Rec: 0.710, F1: 0.733
#      ➤ F1-score: 0.733, Accuracy: 0.970
# ✅ F1 scores saved to: /content/drive/MyDrive/00_RESEARCH_MSC_00/Final_Phonetic_Identification/03_Evaluation_metrics_of_probes/f1_scores.csv
# ✅ Accuracy scores saved to: /content/drive/MyDrive/00_RESEARCH_MSC_00/Final_Phonetic_Identification/03_Evaluation_metrics_of_probes/accuracy_scores.csv
#
# ✅ All layers and features have been trained, evaluated, and saved successfully.
# <ipython-input-43-e1785c8ded5e>:36: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   f1_df = pd.concat([f1_df, pd.DataFrame([row_f1])], ignore_index=True)
# <ipython-input-43-e1785c8ded5e>:37: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   acc_df = pd.concat([acc_df, pd.DataFrame([row_acc])], ignore_index=True)
