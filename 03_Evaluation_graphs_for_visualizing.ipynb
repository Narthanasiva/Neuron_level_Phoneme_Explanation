# %% [markdown]
# <a href="https://colab.research.google.com/github/Narthanasiva/Neuron_level_Phoneme_Explanation/blob/main/03_Evaluation_graphs_for_visualizing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **Import libraries and define paths**

# %%
import pandas as pd
import matplotlib.pyplot as plt

# 📁 Load your saved CSV files from Drive
f1_df = pd.read_csv('/content/drive/MyDrive/00_RESEARCH_MSC_00/Final_Phonetic_Identification/03_Evaluation_metrics_of_probes/f1_scores.csv')        # update the path
acc_df = pd.read_csv('/content/drive/MyDrive/00_RESEARCH_MSC_00/Final_Phonetic_Identification/03_Evaluation_metrics_of_probes/accuracy_scores.csv') # update the path

# 🔁 Define features to loop over
features = ["voiced", "fricative", "nasal"]
colors = ["blue", "green", "red"]

# %% [markdown]
# # **F1 score VS Layers**

# %%
# -----------------------------------------
# 📊 1. Plot F1 Score vs Layer
# -----------------------------------------
plt.figure(figsize=(10, 6))
for feat, color in zip(features, colors):
    plt.plot(f1_df["layer"], f1_df[feat], label=feat.capitalize(), color=color, marker='o')

plt.title("F1 Score vs WavLM Layer")
plt.xlabel("WavLM Layer")
plt.ylabel("F1 Score")
plt.xticks(range(13))
plt.ylim([0, 1.0])  # 👈 Set y-axis limits here
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Accuracy VS Layers**

# %%
# -----------------------------------------
# 📊 2. Plot Accuracy vs Layer
# -----------------------------------------
plt.figure(figsize=(10, 6))
for feat, color in zip(features, colors):
    plt.plot(acc_df["layer"], acc_df[feat], label=feat.capitalize(), color=color, marker='o')

plt.title("Accuracy vs WavLM Layer")
plt.xlabel("WavLM Layer")
plt.ylabel("Accuracy")
plt.xticks(range(13))
plt.ylim([0, 1.0])  # 👈 Set y-axis limits here
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
